# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnupriya-lakkoju/python-projects/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#introduction to ML
#used libraries - random,numpy,pandas
import random

# %%
#terms in machine learning
#1.collection: data used for training,validating and testing the machine learning model
#2.feature: independent variable or input variable used to predict the target variable denoted by "X"
#3.target: dependent variable or output variable but we want to predict
#Ex: predicting no of bedrooms
#4.training data: subset of dataset used to train the model
#5.testing data: subset of dataset used to validate the trained model
#6.model: mathematical representation of relationship between feature and target
#7.supervised learning(SL): training the data based on labeled data\ the model learns from known or labeled data
#8.regression: method to predict continuous values
