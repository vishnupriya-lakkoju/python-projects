# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
datasetpath=('/content/drive/MyDrive/matches_1930_2022 (1).csv')

# %%
df=pd.read_csv(datasetpath)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df.columns
# Out:
# Index(['home_team', 'away_team', 'home_score', 'home_xg', 'home_penalty',
#        'away_score', 'away_xg', 'away_penalty', 'home_manager', 'home_captain',
#        'away_manager', 'away_captain', 'Attendance', 'Venue', 'Officials',
#        'Round', 'Date', 'Score', 'Referee', 'Notes', 'Host', 'Year',
#        'home_goal', 'away_goal', 'home_goal_long', 'away_goal_long',
#        'home_own_goal', 'away_own_goal', 'home_penalty_goal',
#        'away_penalty_goal', 'home_penalty_miss_long', 'away_penalty_miss_long',
#        'home_penalty_shootout_goal_long', 'away_penalty_shootout_goal_long',
#        'home_penalty_shootout_miss_long', 'away_penalty_shootout_miss_long',
#        'home_red_card', 'away_red_card', 'home_yellow_red_card',
#        'away_yellow_red_card', 'home_yellow_card_long',
#        'away_yellow_card_long', 'home_substitute_in_long',
#        'away_substitute_in_long'],
#       dtype='object')

# %%
df['home_team'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 964 entries, 0 to 963
# Series name: home_team
# Non-Null Count  Dtype
# --------------  -----
# 964 non-null    object
# dtypes: object(1)
# memory usage: 7.7+ KB

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# Date
# 1958-06-15    8
# 1958-06-08    8
# 1934-05-27    8
# 1958-06-11    7
# 1938-06-05    6
#              ..
# 2006-07-08    1
# 2006-07-05    1
# 2006-07-04    1
# 1966-07-25    1
# 2022-12-18    1
# Name: count, Length: 378, dtype: int64

# %%
df['Score'].value_counts()
# Out:
# Score
# 1–0            118
# 2–1            107
# 1–1             75
# 2–0             71
# 0–0             66
#               ...
# (4) 2–2 (3)      1
# (3) 0–0 (2)      1
# (4) 2–2 (5)      1
# (4) 1–1 (3)      1
# 6–5              1
# Name: count, Length: 71, dtype: int64

# %%
scoreabovezero=df['score']>'0-0'

# %%
df[scoreabovezero].shape or df.shape
# Out:
# (0, 45)

# %%
scorebyBscore=df['home_team']=='Brazil'

# %%
brazildf=df[scorebyBscore].sort_values(by='home_score',ascending=True)

# %%
brazildf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, 384 to 893
# Data columns (total 45 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   home_team                        85 non-null     object
#  1   away_team                        85 non-null     object
#  2   home_score                       85 non-null     int64
#  3   home_xg                          7 non-null      float64
#  4   home_penalty                     4 non-null      float64
#  5   away_score                       85 non-null     int64
#  6   away_xg                          7 non-null      float64
#  7   away_penalty                     4 non-null      float64
#  8   home_manager                     85 non-null     object
#  9   home_captain                     61 non-null     object
#  10  away_manager                     85 non-null     object
#  11  away_captain                     61 non-null     object
# ...

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
brazildf.plot(x='home_score',y='away_score',kind='scatter')
plt.xlabel('Home Score')
plt.ylabel('Away Score')
plt.legend('Take Away Score')
plt.title('Brazil Matches')
plt.show()

# %%
def AnalyzeFrance():
   matchesPlayed=df['home_team'].value_counts()['France']
   print(f'Total no of matches played by frnace is :{matchesPlayed}')

# %%
AnalyzeFrance()
# Out:
# Total no of matches played by frnace is :38

# %%
type(df['home_team'].value_counts())
# Out:
# pandas.core.series.Series

# %%
def AnalyzeTowns():
  TownData=df['home_team'].value_counts()
  for _ in TownData.index:
    print(f'Total Number of matches played by{_} is :{TownData[_]}')

# %%
AnalyzeTowns()
# Out:
# Total Number of matches played byBrazil is :85
# Total Number of matches played byArgentina is :59
# Total Number of matches played byItaly is :57
# Total Number of matches played byEngland is :40
# Total Number of matches played byGermany is :40
# Total Number of matches played byFrance is :38
# Total Number of matches played byWest Germany is :38
# Total Number of matches played bySpain is :34
# Total Number of matches played byNetherlands is :33
# Total Number of matches played byUruguay is :33
# Total Number of matches played bySweden is :30
# Total Number of matches played byBelgium is :23
# Total Number of matches played byPortugal is :21
# Total Number of matches played byPoland is :20
# Total Number of matches played bySoviet Union is :18
# Total Number of matches played byHungary is :18
# Total Number of matches played byMexico is :18
# Total Number of matches played byKorea Republic is :18
# Total Number of matches played bySwitzerland is :16
# ...

# %%
# %matplotlib inline

# %%
Town30=df['home_team'].value_counts().values>30

# %%
Town30
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
townName=[]
matchesPlayed=[]
TownData=df['home_team'].value_counts()
for _ in TownData.index:
  if TownData[_]>30:
      townName.append(_)
      matchesPlayed.append(TownData[_])

# %%
townName
# Out:
# ['Brazil',
#  'Argentina',
#  'Italy',
#  'England',
#  'Germany',
#  'France',
#  'West Germany',
#  'Spain',
#  'Netherlands',
#  'Uruguay']

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(townName, matchesPlayed)
plt.xlabel('Town Name')
plt.ylabel('Matches played')
plt.title('Matches played by town')
plt.show()

# %%
plt.bar(townName, matchesPlayed)
plt.xlabel('Town Name')
plt.ylabel('Matches played')
plt.title('Matches played by town')
plt.show()

# %%
plt.scatter(townName, matchesPlayed)
plt.xlabel('Town Name')
plt.ylabel('Matches played')
plt.title('Matches played by town')
plt.show()

# %%
plt.barh(townName, matchesPlayed)
plt.xlabel('Town Name')
plt.ylabel('Matches played')
plt.title('Matches played by town')
plt.show()

# %%
Above30 = df['home_team'].value_counts()

# %%
filteredData=Above30[Above30>30]

# %%
filteredData.plot(kind='bar')
# Out:
# <Axes: xlabel='home_team'>

# %%
filteredData.plot(kind='area')
# Out:
# <Axes: xlabel='home_team'>

# %%
filteredData.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
def MatchesPlayedByTown():
 townName=[]
 matchesPlayed=[]
 TownData=df['home_team'].value_counts()
for _ in TownData.index:
  if TownData[_]>30:
      townName.append(_)
      matchesPlayed.append(TownData[_])
      plt.plot(townName, matchesPlayed)
plt.xlabel('Town Name')
plt.ylabel('Matches played')
plt.title('Matches played by town')
plt.show()

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
filteredData = df['home_team'].value_counts()

# %%
f2=filteredData[filteredData>=40]

# %%
f2
# Out:
# home_team
# Brazil       85
# Argentina    59
# Italy        57
# England      40
# Germany      40
# Name: count, dtype: int64

# %%
df[df['home_team'].isin(f2)]
# Out:
# Empty DataFrame
# Columns: [home_team, away_team, home_score, home_xg, home_penalty, away_score, away_xg, away_penalty, home_manager, home_captain, away_manager, away_captain, Attendance, Venue, Officials, Round, Date, Score, Referee, Notes, Host, Year, home_goal, away_goal, home_goal_long, away_goal_long, home_own_goal, away_own_goal, home_penalty_goal, away_penalty_goal, home_penalty_miss_long, away_penalty_miss_long, home_penalty_shootout_goal_long, away_penalty_shootout_goal_long, home_penalty_shootout_miss_long, away_penalty_shootout_miss_long, home_red_card, away_red_card, home_yellow_red_card, away_yellow_red_card, home_yellow_card_long, away_yellow_card_long, home_substitute_in_long, away_substitute_in_long]
# Index: []
#
# [0 rows x 44 columns]

# %%
df.shape
# Out:
# (964, 44)

# %%
age=[]
height=[]
weight=[]

# %%
import random

# %%
[age.append(random.randint(10,40)) for _ in range(964)]
print(f"Age is now having {len(age)}")
# Out:
# Age is now having 964

# %%
age
# Out:
# [39,
#  16,
#  30,
#  40,
#  13,
#  34,
#  40,
#  37,
#  36,
#  32,
#  12,
#  25,
#  40,
#  35,
#  18,
#  36,
#  26,
#  21,
#  40,
#  18,
#  37,
#  20,
#  12,
#  22,
#  32,
#  17,
#  20,
#  29,
#  20,
#  26,
#  32,
#  27,
#  14,
#  19,
#  23,
#  17,
#  35,
#  37,
#  22,
#  32,
#  14,
#  14,
#  22,
#  40,
#  32,
#  27,
#  10,
#  27,
#  36,
#  24,
#  33,
#  26,
#  39,
#  10,
#  38,
#  20,
#  27,
#  19,
#  23,
#  37,
#  30,
#  38,
#  29,
#  34,
#  24,
#  12,
#  24,
#  34,
#  32,
#  38,
#  24,
#  18,
#  38,
#  25,
#  29,
#  17,
#  12,
#  27,
#  14,
#  10,
#  10,
#  20,
#  24,
#  26,
#  29,
#  17,
#  24,
#  20,
#  21,
#  15,
#  28,
#  20,
#  34,
#  29,
#  24,
#  36,
#  24,
#  37,
#  35,
#  39,
#  31,
#  21,
#  40,
#  34,
#  34,
#  40,
#  17,
#  34,
#  31,
#  36,
#  21,
#  25,
#  32,
#  18,
#  39,
#  12,
#  14,
#  14,
#  32,
#  32,
#  23,
#  37,
#  17,
#  38,
#  30,
#  34,
#  36,
#  24,
#  22,
#  12,
#  18,
#  11,
#  33,
#  10,
#  17,
#  33,
#  24,
#  12,
#  10,
#  37,
#  22,
#  34,
# ...

# %%
#Adding a new column to the DFrame
#syntax:df['newcolumn']=list/series of elements
df['YearsofExperience']=age

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df['ASP']=df['YearsofExperience']-df['home_score']

# %%
df.shape
# Out:
# (964, 46)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df['ASP'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df.plot(x='ASP',y=['away_score','home_score'],kind='bar',color=['Red','Green'])
# Out:
# <Axes: xlabel='ASP'>

# %%
def getGraph(DataFrame,Column1,Column2):
  from matplotlib import pyplot as plt
  if len(DataFrame[Column1]) == len(DataFrame[Column2]):
      df.plot(x=Column1, y=Column2, kind='bar', color=['black','pink'])
      print('The graph/plot is succesfully created')

  else:
    print('please check the Column size once')

# %%
getGraph(df,'home_score','away_score')
# Out:
# The graph/plot is succesfully created
