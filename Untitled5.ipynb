# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnupriya-lakkoju/python-projects/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
idata={'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [39,
#   65,
#   75,
#   12,
#   10,
#   100,
#   96,
#   88,
#   89,
#   1,
#   19,
#   19,
#   92,
#   23,
#   60,
#   31,
#   86,
#   32,
#   54,
#   72,
#   96,
#   52,
#   53,
#   96,
#   89,
#   11,
#   11,
#   54,
#   93,
#   40,
#   51,
#   94,
#   40,
#   91,
#   23,
#   19,
#   9,
#   33,
#   53,
#   46,
#   31,
#   36,
#   96,
#   54,
#   52,
#   18,
#   63,
#   40,
#   86,
#   91,
#   78,
#   91,
#   3,
#   42,
#   85,
#   0,
#   100,
#   100,
#   86,
#   80,
#   16,
#   71,
#   32,
#   85,
#   73,
#   66,
#   25,
#   1,
#   70,
#   48,
#   77,
#   6,
#   65,
#   76,
#   10,
#   52,
#   81,
#   82,
#   70,
#   64,
#   73,
#   87,
#   38,
#   72,
#   55,
#   42,
#   9,
#   57,
#   45,
#   0,
#   71,
#   91,
#   72,
#   20,
#   4,
#   51,
#   99,
#   36,
#   86,
#   27],
#  'Height': [78,
#   86,
#   15,
#   62,
#   37,
#   96,
#   87,
#   48,
#   64,
#   44,
#   28,
#   99,
#   14,
#   5,
#   47,
#   46,
#   5,
#   17,
#   52,
#   54,
#   12,
#   17,
#   35,
#   91,
#   14,
#   90,
#   58,
#   100,
#   53,
#   99,
#   48,
#   76,
#   5,
#   40,
#   2,
#   71,
#   39,
#   21,
#   98,
#   13,
#   81,
#   44,
#   99,
#   4,
#   54,
#   4,
#   82,
#   65,
#   59,
#   19,
#   64,
#   5,
#   56,
#   23,
#   33,
#   38,
#   1,
#   40,
#   30,
#   86,
#   93,
#   80,
#   60,
#   81,
#   98,
#   0,
#   46,
#   75,
#   76,
#   100,
#   52,
#   85,
#   6,
#   20,
#   23,
#   53,
#   9,
#   51,
#   13,
#   81,
#   80,
#   31,
#   72,
#   90,
#   64,
#   60,
#   59,
#   6,
#   76,
#   34,
#   69,
#   80,
#   36,
#   5,
#   35,
#   86,
#   14,
#   51,
#   49,
#   99],
#  'Weight': [9,
#   66,
#   4,
#   62,
#   54,
#   4,
#   90,
#   90,
#   69,
#   50,
#   91,
#   20,
#   7,
#   22,
#   18,
#   38,
#   17,
#   16,
#   85,
#   51,
#   53,
#   88,
#   77,
#   20,
#   22,
#   71,
#   73,
#   56,
#   33,
#   28,
#   53,
#   73,
#   49,
#   26,
#   10,
#   88,
#   51,
#   58,
#   66,
#   57,
#   23,
#   67,
#   1,
#   82,
#   7,
#   39,
#   80,
#   26,
#   96,
#   52,
#   69,
#   16,
#   4,
#   91,
#   53,
#   54,
#   92,
#   59,
#   68,
#   4,
#   67,
#   16,
#   22,
#   66,
#   18,
#   89,
#   78,
#   22,
#   99,
#   66,
#   45,
#   85,
#   86,
#   82,
#   14,
#   79,
#   26,
#   16,
#   28,
#   81,
#   7,
#   14,
#   27,
#   92,
#   82,
#   85,
#   17,
#   24,
#   72,
#   99,
#   14,
#   4,
#   95,
#   66,
#   44,
#   96,
#   67,
#   92,
#   48,
#   21],
#  'Speed': [69,
#   11,
#   53,
#   100,
#   29,
#   9,
#   50,
#   51,
#   74,
#   19,
#   41,
#   15,
#   47,
#   75,
#   31,
#   84,
#   44,
#   27,
#   13,
#   97,
#   20,
#   66,
#   3,
#   63,
#   100,
#   34,
#   97,
#   71,
#   9,
#   34,
#   90,
#   56,
#   74,
#   0,
#   39,
#   80,
#   43,
#   51,
#   96,
#   87,
#   25,
#   99,
#   7,
#   56,
#   99,
#   25,
#   73,
#   6,
#   88,
#   91,
#   5,
#   66,
#   32,
#   52,
#   4,
#   78,
#   14,
#   58,
#   70,
#   82,
#   86,
#   56,
#   56,
#   9,
#   93,
#   46,
#   11,
#   44,
#   87,
#   64,
#   25,
#   2,
#   72,
#   14,
#   36,
#   98,
#   58,
#   25,
#   70,
#   6,
#   99,
#   71,
#   48,
#   92,
#   60,
#   65,
#   83,
#   99,
#   65,
#   2,
#   55,
#   62,
#   40,
#   45,
#   67,
#   81,
#   72,
#   81,
#   18,
#   67]}

# %%
df1=pd.DataFrame(idata)

# %%
df1.describe()
# Out:
#               Age     Height      Weight       Speed
# count  100.000000  100.00000  100.000000  100.000000
# mean    54.540000   50.51000   50.490000   53.120000
# std     30.443994   30.69284   30.275668   30.179356
# min      0.000000    0.00000    1.000000    0.000000
# 25%     31.000000   22.50000   21.750000   26.500000
# 50%     54.000000   51.50000   53.000000   56.000000
# 75%     82.750000   78.50000   78.250000   75.750000
# max    100.000000  100.00000   99.000000  100.000000

# %%
df1.sort_index(ascending=False)
# Out:
#     Age  Height  Weight  Speed
# 99   27      99      21     67
# 98   86      49      48     18
# 97   36      51      92     81
# 96   99      14      67     72
# 95   51      86      96     81
# ..  ...     ...     ...    ...
# 4    10      37      54     29
# 3    12      62      62    100
# 2    75      15       4     53
# 1    65      86      66     11
# 0    39      78       9     69
#
# [100 rows x 4 columns]

# %%
df1.sort_index(ascending=True)
# Out:
#     Age  Height  Weight  Speed
# 0    39      78       9     69
# 1    65      86      66     11
# 2    75      15       4     53
# 3    12      62      62    100
# 4    10      37      54     29
# ..  ...     ...     ...    ...
# 95   51      86      96     81
# 96   99      14      67     72
# 97   36      51      92     81
# 98   86      49      48     18
# 99   27      99      21     67
#
# [100 rows x 4 columns]

# %%
df1['Weight']>50
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4      True
#       ...
# 95     True
# 96     True
# 97     True
# 98    False
# 99    False
# Name: Weight, Length: 100, dtype: bool

# %%
filter1=df1['Weight']>50

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 1    65      86      66     11
# 3    12      62      62    100
# 4    10      37      54     29
# 6    96      87      90     50
# 7    88      48      90     51
# 8    89      64      69     74
# 10   19      28      91     41
# 18   54      52      85     13
# 19   72      54      51     97
# 20   96      12      53     20
# 21   52      17      88     66
# 22   53      35      77      3
# 25   11      90      71     34
# 26   11      58      73     97
# 27   54     100      56     71
# 30   51      48      53     90
# 31   94      76      73     56
# 35   19      71      88     80
# 36    9      39      51     43
# 37   33      21      58     51
# 38   53      98      66     96
# 39   46      13      57     87
# 41   36      44      67     99
# 43   54       4      82     56
# 46   63      82      80     73
# 48   86      59      96     88
# 49   91      19      52     91
# 50   78      64      69      5
# 53   42      23      91     52
# 54   85      33      53      4
# 55    0      38      54     78
# 56  100       1      92     14
# 57  100      40      59     58
# 58   86      30      68     70
# 60   16      93      67     86
# 63   85      81      66      9
# 65   66       0      89     46
# 66   25      46      78     11
# 68   70      76      99     87
# 69   48     100      66     64
# 71    6      85      85      2
# 72   65       6      86     72
# 73   76      20      82     14
# 75   52      53      79     98
# 79   64      81      81      6
# 83   72      90      92     92
# 84   55      64      82     60
# 85   42      60      85     65
# 88   45      76      72     65
# 89    0      34      99      2
# 92   72      36      95     40
# 93   20       5      66     45
# 95   51      86      96     81
# 96   99      14      67     72
# 97   36      51      92     81

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 1    65      86      66     11
# 3    12      62      62    100
# 4    10      37      54     29
# 6    96      87      90     50
# 7    88      48      90     51
# 8    89      64      69     74
# 10   19      28      91     41
# 18   54      52      85     13
# 19   72      54      51     97
# 20   96      12      53     20
# 21   52      17      88     66
# 22   53      35      77      3
# 25   11      90      71     34
# 26   11      58      73     97
# 27   54     100      56     71
# 30   51      48      53     90
# 31   94      76      73     56
# 35   19      71      88     80
# 36    9      39      51     43
# 37   33      21      58     51
# 38   53      98      66     96
# 39   46      13      57     87
# 41   36      44      67     99
# 43   54       4      82     56
# 46   63      82      80     73
# 48   86      59      96     88
# 49   91      19      52     91
# 50   78      64      69      5
# 53   42      23      91     52
# 54   85      33      53      4
# 55    0      38      54     78
# 56  100       1      92     14
# 57  100      40      59     58
# 58   86      30      68     70
# 60   16      93      67     86
# 63   85      81      66      9
# 65   66       0      89     46
# 66   25      46      78     11
# 68   70      76      99     87
# 69   48     100      66     64
# 71    6      85      85      2
# 72   65       6      86     72
# 73   76      20      82     14
# 75   52      53      79     98
# 79   64      81      81      6
# 83   72      90      92     92
# 84   55      64      82     60
# 85   42      60      85     65
# 88   45      76      72     65
# 89    0      34      99      2
# 92   72      36      95     40
# 93   20       5      66     45
# 95   51      86      96     81
# 96   99      14      67     72
# 97   36      51      92     81

# %%
filter2=df1['Age']>50

# %%
df1[filter1 | filter2]
# Out:
#     Age  Height  Weight  Speed
# 1    65      86      66     11
# 2    75      15       4     53
# 3    12      62      62    100
# 4    10      37      54     29
# 5   100      96       4      9
# ..  ...     ...     ...    ...
# 93   20       5      66     45
# 95   51      86      96     81
# 96   99      14      67     72
# 97   36      51      92     81
# 98   86      49      48     18
#
# [80 rows x 4 columns]

# %%
df1.loc[filter1 & filter2]
# Out:
#     Age  Height  Weight  Speed
# 1    65      86      66     11
# 6    96      87      90     50
# 7    88      48      90     51
# 8    89      64      69     74
# 18   54      52      85     13
# 19   72      54      51     97
# 20   96      12      53     20
# 21   52      17      88     66
# 22   53      35      77      3
# 27   54     100      56     71
# 30   51      48      53     90
# 31   94      76      73     56
# 38   53      98      66     96
# 43   54       4      82     56
# 46   63      82      80     73
# 48   86      59      96     88
# 49   91      19      52     91
# 50   78      64      69      5
# 54   85      33      53      4
# 56  100       1      92     14
# 57  100      40      59     58
# 58   86      30      68     70
# 63   85      81      66      9
# 65   66       0      89     46
# 68   70      76      99     87
# 72   65       6      86     72
# 73   76      20      82     14
# 75   52      53      79     98
# 79   64      81      81      6
# 83   72      90      92     92
# 84   55      64      82     60
# 92   72      36      95     40
# 95   51      86      96     81
# 96   99      14      67     72
